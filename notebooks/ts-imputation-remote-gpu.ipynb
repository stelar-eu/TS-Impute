# %% [markdown]
# ### TS-Imputation Invocation Notebook — Remote Execution with GPU (CUDA 12) - example

# %%
from stelar.client import Client, TaskSpec


# Instantiate the client with the base URL and personal credentials
c = Client(base_url="https://klms.stelar.gr", username="***", password="***")

# %%
proc = c.processes["759d9454-a3c2-4e37-a4ed-54c8ef0f885e"]
print(f"Browse workflow process at {c._base_url}/console/v1/process/{str(proc.id)}")
# Out:
# Browse workflow process at https://klms.stelar.gr/stelar/console/v1/process/759d9454-a3c2-4e37-a4ed-54c8ef0f885e

# %%
t = TaskSpec(name=f"TS-Imputation Remote Example with GPU")

# Set the input missing timeseries file
t.i(missing="56ee301f-0d9e-4433-8b0b-0094647c850a", ground_truth="e4d6257d-a0a4-4b04-bf3d-9ae1c8cc234e")

t.d(alias="d0", dset="afab46b4-42d7-4cbe-84be-798a4b77a167")

# Set the destination path for the imputed timeseries
t.o(
    imputed_timeseries={
        "url": f"s3://test-bucket/test_imputation/gpu_test_imputed_timeseries.csv",
        "resource": {
            "name": f"Imputed timeseries",
            "relation": "imputed_timeseries",
        },
        "dataset": "d0",
    }
)

# Set the parameters for the task
p_spec = {
    "time_column": "time",
    "time_format": "%Y-%m-%d",
    "sep": ",",
    "header": 0,
    "hyperparameter_tuning": False,
    "is_multivariate": False,
    "n_trials": 50,
    "tuning_top_k_fewer_missing": 15000,
    "imp_method": "saits",
    "default": True,
    "params": {}
}

t.p(**p_spec)

# Run the task
ts_impute_t = proc.run(t)
print(
    f"Browse the task at {c._base_url}/console/v1/task/{str(proc.id)}/{str(ts_impute_t.id)}"
)
# Out:
# Browse the task at https://klms.stelar.gr/stelar/console/v1/task/759d9454-a3c2-4e37-a4ed-54c8ef0f885e/0f0524cc-0e3b-4bfe-8dbf-10d42e564882

# %%
import subprocess

image_name = "img.stelar.gr/stelar/ts-imputation:latest"

ts_id = ts_impute_t.id
ts_signature = ts_impute_t.signature

docker_command = [
    "docker",
    "run",
    "--rm",
    "--gpus",
    "all",
    image_name,
    "Bearer " + c.token,
    c.api_url.rstrip("/api/"),
    str(ts_id),
    ts_signature,
]

try:
    subprocess.run(docker_command, check=True)
    print("Docker command executed successfully.")
except subprocess.CalledProcessError as e:
    print(f"Error occurred while executing Docker command: {e}")
# Out:
# [STELAR INFO] Performing cURL to the KLMS API to fetch input...
# [STELAR INFO] Tool input was fetched from the API endpoint V2.
#
# Executing saits
# 2025-08-05 12:47:45 [INFO]: Have set the random seed as 2025 for numpy and pytorch.
# 2025-08-05 12:47:45 [INFO]: No given device, using default device: cuda
# 2025-08-05 12:47:45 [WARNING]: ‼️ saving_path not given. Model files and tensorboard file will not be saved.
# 2025-08-05 12:47:45 [INFO]: SAITS initialized with the given hyperparameters, the number of trainable parameters: 200,719
# 2025-08-05 12:47:46 [INFO]: Epoch 001 - training loss (MSE): 6.9702
# 2025-08-05 12:47:46 [INFO]: Epoch 002 - training loss (MSE): 2.0544
# 2025-08-05 12:47:46 [INFO]: Epoch 003 - training loss (MSE): 1.7658
# 2025-08-05 12:47:46 [INFO]: Epoch 004 - training loss (MSE): 1.9822
# 2025-08-05 12:47:46 [INFO]: Epoch 005 - training loss (MSE): 1.6332
# 2025-08-05 12:47:46 [INFO]: Epoch 006 - training loss (MSE): 1.5445
# 2025-08-05 12:47:47 [INFO]: Epoch 007 - training loss (MSE): 1.3550
# 2025-08-05 12:47:47 [INFO]: Epoch 008 - training loss (MSE): 1.2737
# 2025-08-05 12:47:47 [INFO]: Epoch 009 - training loss (MSE): 1.1465
# 2025-08-05 12:47:47 [INFO]: Epoch 010 - training loss (MSE): 1.0019
# 2025-08-05 12:47:47 [INFO]: Epoch 011 - training loss (MSE): 0.8424
# 2025-08-05 12:47:47 [INFO]: Epoch 012 - training loss (MSE): 0.7782
# 2025-08-05 12:47:47 [INFO]: Epoch 013 - training loss (MSE): 1.2441
# 2025-08-05 12:47:47 [INFO]: Epoch 014 - training loss (MSE): 0.9456
# 2025-08-05 12:47:47 [INFO]: Epoch 015 - training loss (MSE): 0.7928
# 2025-08-05 12:47:47 [INFO]: Epoch 016 - training loss (MSE): 0.6977
# 2025-08-05 12:47:47 [INFO]: Epoch 017 - training loss (MSE): 0.5861
# 2025-08-05 12:47:47 [INFO]: Epoch 018 - training loss (MSE): 0.5608
# 2025-08-05 12:47:47 [INFO]: Epoch 019 - training loss (MSE): 0.5027
# 2025-08-05 12:47:48 [INFO]: Epoch 020 - training loss (MSE): 0.4571
# 2025-08-05 12:47:48 [INFO]: Epoch 021 - training loss (MSE): 0.4117
# 2025-08-05 12:47:48 [INFO]: Epoch 022 - training loss (MSE): 0.3787
# 2025-08-05 12:47:48 [INFO]: Epoch 023 - training loss (MSE): 0.3587
# 2025-08-05 12:47:48 [INFO]: Epoch 024 - training loss (MSE): 0.3360
# 2025-08-05 12:47:48 [INFO]: Epoch 025 - training loss (MSE): 0.3235
# 2025-08-05 12:47:48 [INFO]: Epoch 026 - training loss (MSE): 0.3211
# 2025-08-05 12:47:48 [INFO]: Epoch 027 - training loss (MSE): 0.2951
# 2025-08-05 12:47:48 [INFO]: Epoch 028 - training loss (MSE): 0.2795
# 2025-08-05 12:47:48 [INFO]: Epoch 029 - training loss (MSE): 0.2745
# 2025-08-05 12:47:48 [INFO]: Epoch 030 - training loss (MSE): 0.2632
# 2025-08-05 12:47:48 [INFO]: Epoch 031 - training loss (MSE): 0.2497
# 2025-08-05 12:47:48 [INFO]: Epoch 032 - training loss (MSE): 0.2451
# 2025-08-05 12:47:49 [INFO]: Epoch 033 - training loss (MSE): 0.2271
# 2025-08-05 12:47:49 [INFO]: Epoch 034 - training loss (MSE): 0.2214
# 2025-08-05 12:47:49 [INFO]: Epoch 035 - training loss (MSE): 0.2197
# 2025-08-05 12:47:49 [INFO]: Epoch 036 - training loss (MSE): 0.2094
# 2025-08-05 12:47:49 [INFO]: Epoch 037 - training loss (MSE): 0.2012
# 2025-08-05 12:47:49 [INFO]: Epoch 038 - training loss (MSE): 0.1990
# 2025-08-05 12:47:49 [INFO]: Epoch 039 - training loss (MSE): 0.1943
# 2025-08-05 12:47:49 [INFO]: Epoch 040 - training loss (MSE): 0.1853
# 2025-08-05 12:47:49 [INFO]: Epoch 041 - training loss (MSE): 0.1840
# 2025-08-05 12:47:49 [INFO]: Epoch 042 - training loss (MSE): 0.1765
# 2025-08-05 12:47:49 [INFO]: Epoch 043 - training loss (MSE): 0.1680
# 2025-08-05 12:47:49 [INFO]: Epoch 044 - training loss (MSE): 0.1726
# 2025-08-05 12:47:50 [INFO]: Epoch 045 - training loss (MSE): 0.1695
# 2025-08-05 12:47:50 [INFO]: Epoch 046 - training loss (MSE): 0.1668
# 2025-08-05 12:47:50 [INFO]: Epoch 047 - training loss (MSE): 0.1643
# 2025-08-05 12:47:50 [INFO]: Epoch 048 - training loss (MSE): 0.1577
# 2025-08-05 12:47:50 [INFO]: Epoch 049 - training loss (MSE): 0.1565
# 2025-08-05 12:47:50 [INFO]: Epoch 050 - training loss (MSE): 0.1499
# 2025-08-05 12:47:50 [INFO]: Epoch 051 - training loss (MSE): 0.1520
# 2025-08-05 12:47:50 [INFO]: Epoch 052 - training loss (MSE): 0.1526
# 2025-08-05 12:47:50 [INFO]: Epoch 053 - training loss (MSE): 0.1392
# 2025-08-05 12:47:50 [INFO]: Epoch 054 - training loss (MSE): 0.1381
# 2025-08-05 12:47:50 [INFO]: Epoch 055 - training loss (MSE): 0.1366
# 2025-08-05 12:47:50 [INFO]: Epoch 056 - training loss (MSE): 0.1297
# 2025-08-05 12:47:50 [INFO]: Epoch 057 - training loss (MSE): 0.1297
# 2025-08-05 12:47:51 [INFO]: Epoch 058 - training loss (MSE): 0.1293
# 2025-08-05 12:47:51 [INFO]: Epoch 059 - training loss (MSE): 0.1241
# 2025-08-05 12:47:51 [INFO]: Epoch 060 - training loss (MSE): 0.1231
# 2025-08-05 12:47:51 [INFO]: Epoch 061 - training loss (MSE): 0.1196
# 2025-08-05 12:47:51 [INFO]: Epoch 062 - training loss (MSE): 0.1213
# 2025-08-05 12:47:51 [INFO]: Epoch 063 - training loss (MSE): 0.1176
# 2025-08-05 12:47:51 [INFO]: Epoch 064 - training loss (MSE): 0.1156
# 2025-08-05 12:47:51 [INFO]: Epoch 065 - training loss (MSE): 0.1158
# 2025-08-05 12:47:51 [INFO]: Epoch 066 - training loss (MSE): 0.1159
# 2025-08-05 12:47:51 [INFO]: Epoch 067 - training loss (MSE): 0.1159
# 2025-08-05 12:47:51 [INFO]: Epoch 068 - training loss (MSE): 0.1124
# 2025-08-05 12:47:51 [INFO]: Epoch 069 - training loss (MSE): 0.1057
# 2025-08-05 12:47:51 [INFO]: Epoch 070 - training loss (MSE): 0.1073
# 2025-08-05 12:47:52 [INFO]: Epoch 071 - training loss (MSE): 0.1071
# 2025-08-05 12:47:52 [INFO]: Epoch 072 - training loss (MSE): 0.1065
# 2025-08-05 12:47:52 [INFO]: Epoch 073 - training loss (MSE): 0.1047
# 2025-08-05 12:47:52 [INFO]: Epoch 074 - training loss (MSE): 0.1114
# 2025-08-05 12:47:52 [INFO]: Epoch 075 - training loss (MSE): 0.1015
# 2025-08-05 12:47:52 [INFO]: Epoch 076 - training loss (MSE): 0.1030
# 2025-08-05 12:47:52 [INFO]: Epoch 077 - training loss (MSE): 0.1027
# 2025-08-05 12:47:52 [INFO]: Epoch 078 - training loss (MSE): 0.1005
# 2025-08-05 12:47:52 [INFO]: Epoch 079 - training loss (MSE): 0.1000
# 2025-08-05 12:47:52 [INFO]: Epoch 080 - training loss (MSE): 0.0953
# 2025-08-05 12:47:52 [INFO]: Epoch 081 - training loss (MSE): 0.0972
# 2025-08-05 12:47:52 [INFO]: Epoch 082 - training loss (MSE): 0.0946
# 2025-08-05 12:47:52 [INFO]: Epoch 083 - training loss (MSE): 0.0951
# 2025-08-05 12:47:53 [INFO]: Epoch 084 - training loss (MSE): 0.0937
# 2025-08-05 12:47:53 [INFO]: Epoch 085 - training loss (MSE): 0.0907
# 2025-08-05 12:47:53 [INFO]: Epoch 086 - training loss (MSE): 0.0907
# 2025-08-05 12:47:53 [INFO]: Epoch 087 - training loss (MSE): 0.0905
# 2025-08-05 12:47:53 [INFO]: Epoch 088 - training loss (MSE): 0.0903
# 2025-08-05 12:47:53 [INFO]: Epoch 089 - training loss (MSE): 0.0879
# 2025-08-05 12:47:53 [INFO]: Epoch 090 - training loss (MSE): 0.0872
# 2025-08-05 12:47:53 [INFO]: Epoch 091 - training loss (MSE): 0.0864
# 2025-08-05 12:47:53 [INFO]: Epoch 092 - training loss (MSE): 0.0845
# 2025-08-05 12:47:53 [INFO]: Epoch 093 - training loss (MSE): 0.0875
# 2025-08-05 12:47:53 [INFO]: Epoch 094 - training loss (MSE): 0.0832
# 2025-08-05 12:47:53 [INFO]: Epoch 095 - training loss (MSE): 0.0862
# 2025-08-05 12:47:53 [INFO]: Epoch 096 - training loss (MSE): 0.0845
# 2025-08-05 12:47:54 [INFO]: Epoch 097 - training loss (MSE): 0.0843
# 2025-08-05 12:47:54 [INFO]: Epoch 098 - training loss (MSE): 0.0824
# 2025-08-05 12:47:54 [INFO]: Epoch 099 - training loss (MSE): 0.0816
# 2025-08-05 12:47:54 [INFO]: Epoch 100 - training loss (MSE): 0.0774
# 2025-08-05 12:47:54 [INFO]: Finished training. The best model is from epoch#100.
# {
#     "message": "TS-Impute Tool Executed Successfully",
#     "output": {
#         "imputed_timeseries": "s3://test-bucket/test_imputation/gpu_test_imputed_timeseries.csv"
#     },
#     "metrics": {
#         "Imputation results for saits": {
#             "Missing value percentage": 3.2709532949456173,
#             "Mean absolute error": 0.18026496718565863,
#             "Mean square error": 0.05690228417202577,
#             "Root mean square error": 0.23854199666311543,
#             "Mean relative error": 0.2288612626919132,
#             "Euclidean Distance": 9.64842665440507,
#             "r2 score": 0.9385171267824609
#         }
#     },
#     "status": "success"
# }
#
# [STELAR INFO] Performing cURL to the KLMS API to propagate output...
# [STELAR INFO] The output request to the KLMS API returned:
# {
#   "help": "Hidden for security reasons",
#   "result": null,
#   "success": true
# }
#
# [STELAR INFO] Tool output was propagated to the API endpoint V2.
# Docker command executed successfully.
